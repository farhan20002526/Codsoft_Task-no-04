# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/MachineLearning/advertising.csv"

# %%
import pandas as pd
df= pd.read_csv(path)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
import matplotlib.pyplot as plt



tv = df["TV"]
radio = df["Radio"]
newspaper = df["Newspaper"]
sales = df["Sales"]

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].scatter(tv, sales)
axes[0].set_title('TV vs. Sales')
axes[0].set_xlabel('TV Advertising Spending')
axes[0].set_ylabel('Sales')

axes[1].scatter(radio, sales)
axes[1].set_title('Radio vs. Sales')
axes[1].set_xlabel('Radio Advertising Spending')
axes[1].set_ylabel('Sales')

axes[2].scatter(newspaper, sales)
axes[2].set_title('Newspaper vs. Sales')
axes[2].set_xlabel('Newspaper Advertising Spending')
axes[2].set_ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# As you can see from the scatter plot that most sales is done by TV and if we talk about the radio and newspaper sales there is not pattern that makes the sales go up as TV .

# %%
total_sales_tv = tv.sum()
total_sales_radio = radio.sum()
total_sales_newspaper = newspaper.sum()

categories = ["TV", "Radio", "Newspaper"]
total_sales = [total_sales_tv, total_sales_radio, total_sales_newspaper]

plt.bar(categories, total_sales, color=['blue', 'green', 'red'])
plt.title('Total Sales by Advertising Medium')
plt.xlabel('Advertising Medium')
plt.ylabel('Total Sales')


plt.show()

# %% [markdown]
# the total sales is done by TV if we compare it with radio or Newspaper so our input will be TV and our output will become the sales

# %% [markdown]
# **Lets begin with data modeling of our data**

# %%
X=df["TV"]
X=X.values.reshape(-1,1)

# %%
Y=df["Sales"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=60)

# %%
print(X_train[0:3])
# Out:
# [[134.3]
#  [ 68.4]
#  [280.7]]

# %%
y_train.head()
# Out:
# 90     14.0
# 83     13.6
# 150    16.1
# 135    11.6
# 125    10.6
# Name: Sales, dtype: float64

# %%
print(X_test[0:3])
# Out:
# [[110.7]
#  [216.4]
#  [ 96.2]]

# %%
y_test.head()
# Out:
# 87     16.0
# 52     22.6
# 144    12.3
# 176    20.2
# 33     17.4
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[17.2]])
# Out:
# array([8.07633078])

# %%
model.score(X_train,y_train)
# Out:
# 0.8178118633893827
